# %%
from qiskit import visualization as v

fig = v.plot_bloch_vector([0,0,1], title = "bloch")
fig

# %%
from qiskit import visualization as v

fig = v.plot_bloch_vector([0,0,-1], title = "bloch")
fig

# %%
from qiskit import visualization as v

fig = v.plot_bloch_vector([1,0,0], title = "bloch")
fig

# %%
from qiskit import visualization as v

fig = v.plot_bloch_vector([-1,0,0], title = "bloch")
fig

# %%
from qiskit import visualization as v

fig = v.plot_bloch_vector([0,-1,0], title = "bloch")
fig

# %%
from qiskit import visualization as v
fig = v.plot_bloch_vector([0,1,0], title = "bloch")
fig
