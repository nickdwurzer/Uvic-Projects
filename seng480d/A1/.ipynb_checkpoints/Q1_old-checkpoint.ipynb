# %% [markdown]
# ## Q1
# #### P1
# The probability of observing 0 with when you apply a Pauli Z gate and then a Hadamard gate is 50% (close to 50% when simulating).
# ![Screen%20Shot%202023-01-23%20at%206.11.49%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%206.11.49%20PM.png)

# %% [markdown]
# #### P2
# <b>|00></b>: When input is |00>, the probability of output being |00> and |11> are both 50%.
# ![Screen%20Shot%202023-01-23%20at%206.38.37%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%206.38.37%20PM.png)

# %% [markdown]
# The measurement results in a slightly different reading of the probability.
# ![Screen%20Shot%202023-01-23%20at%206.57.43%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%206.57.43%20PM.png)

# %% [markdown]
# <b>|01></b>: When input is |01>, the probability of output being |10> and |01> are both 50%.
# ![Screen%20Shot%202023-01-23%20at%207.04.18%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.04.18%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-01-23%20at%207.04.33%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.04.33%20PM.png)

# %% [markdown]
# <b>|10></b>: When input is |10>, the probability of output being |00> and |11> are both 50%.
# ![Screen%20Shot%202023-01-23%20at%207.04.49%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.04.49%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-01-23%20at%207.05.03%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.05.03%20PM.png)

# %% [markdown]
# <b>|11></b>: When input is |11>, the probability of output being |10> and |01> are both 50%.
# ![Screen%20Shot%202023-01-23%20at%207.05.14%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.05.14%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-01-23%20at%207.05.26%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.05.26%20PM.png)

# %% [markdown]
# #### P3
# At barrier one, the quibits states are: $$\frac{1}{2} \Bigl(|00> + |01> + |10> + |11> \Bigr)$$
# This is representative of two qubits where the probability of measuring a |1> oor |0> for either qubit is 50%, thus there is a 25% probability of any of the possible states for the system.
# At barrier two, the quibits states are: $$\frac{1}{2} \Bigl(|00> + |01> + |10> + |11> \Bigr)$$
# The two qubit system has the same probailities as at the last barrier.  This is true because the probabilty of |0> equals the probabilty of |1> for q1.
# ![Screen%20Shot%202023-01-23%20at%207.15.33%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.15.33%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-01-23%20at%207.15.53%20PM.png](attachment:Screen%20Shot%202023-01-23%20at%207.15.53%20PM.png)
